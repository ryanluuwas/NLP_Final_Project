# %%
# Standard
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re
import warnings; warnings.simplefilter('ignore')

# Machine Learning
from scipy import stats
import sklearn
from sklearn import datasets
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import confusion_matrix, precision_score, precision_recall_curve, recall_score, f1_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split

# NLP 
import string
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from nltk.stem.snowball import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk.tokenize import RegexpTokenizer
import nltk
# nltk.download('wordnet')
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from textblob import TextBlob
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
df1 = pd.read_csv("/Users/Adam/Desktop/NLP/earning_calls.csv")
df1.head(n=10)
# Out:
#                                                 href  \
# 0  /earnings/call-transcripts/2020/04/30/microsof...
# 1  /earnings/call-transcripts/2020/01/30/microsof...
# 2  /earnings/call-transcripts/2019/10/23/microsof...
# 3  /earnings/call-transcripts/2019/07/18/microsof...
# 4  /earnings/call-transcripts/2019/04/25/microsof...
# 5  /earnings/call-transcripts/2019/01/31/microsof...
# 6  /earnings/call-transcripts/2018/10/24/microsof...
# 7  /earnings/call-transcripts/2018/07/19/microsof...
# 8  /earnings/call-transcripts/2018/04/26/microsof...
# 9  /earnings/call-transcripts/2018/01/31/microsof...
#
#                                           Transcript Ticker
# 0  ["OperatorGreetings and welcome to the Microso...   msft
# 1  ["OperatorWelcome to the Microsoft Fiscal Year...   msft
# 2  ["OperatorWelcome to the Microsoft Fiscal Year...   msft
# 3  ["OperatorWelcome to the Microsoft Fiscal Year...   msft
# 4  ['Prepared Remarks:', 'Operator', 'Greetings, ...   msft
# 5  ['Contents:', '', 'Prepared Remarks', 'Questio...   msft
# 6  ['Prepared Remarks:', 'Operator', 'Greetings a...   msft
# 7  ['Prepared Remarks:', 'Operator', 'Greetings, ...   msft
# 8  ['Prepared Remarks:', 'Operator', 'Greetings, ...   msft
# 9  ['Prepared Remarks:', 'Operator', 'Welcome to ...   msft

# %%
# Set index
df1['Index'] = range(1, len(df1)+1)
df1.set_index('Index')
# Out:
#                                                     href  \
# Index
# 1      /earnings/call-transcripts/2020/04/30/microsof...
# 2      /earnings/call-transcripts/2020/01/30/microsof...
# 3      /earnings/call-transcripts/2019/10/23/microsof...
# 4      /earnings/call-transcripts/2019/07/18/microsof...
# 5      /earnings/call-transcripts/2019/04/25/microsof...
# ...                                                  ...
# 3491   /earnings/call-transcripts/2019/08/28/coty-inc...
# 3492   /earnings/call-transcripts/2019/05/08/coty-inc...
# 3493   /earnings/call-transcripts/2019/02/08/coty-inc...
# 3494   /earnings/call-transcripts/2018/11/07/coty-inc...
# 3495   /earnings/call-transcripts/2018/08/21/coty-inc...
#
#                                               Transcript Ticker
# Index
# 1      ["OperatorGreetings and welcome to the Microso...   msft
# 2      ["OperatorWelcome to the Microsoft Fiscal Year...   msft
# 3      ["OperatorWelcome to the Microsoft Fiscal Year...   msft
# 4      ["OperatorWelcome to the Microsoft Fiscal Year...   msft
# 5      ['Prepared Remarks:', 'Operator', 'Greetings, ...   msft
# ...                                                  ...    ...
# 3491   ["OperatorGood morning, ladies and gentlemen. ...   coty
# 3492                                                  []   coty
# 3493   ['Contents:', '', 'Prepared Remarks', 'Questio...   coty
# 3494   ['Prepared Remarks:', 'Operator', "Good mornin...   coty
# 3495   ['Prepared Remarks:', 'Operator', "Good mornin...   coty
#
# [3495 rows x 3 columns]

# %%
# Get Date
# Split href
href = df1['href'].str.split("/",n=6,expand=True)
# Drop unnecessary axes
href1 = href.drop([0,1,2,6], axis = 1)
# Rename Axes
href1 = href1.rename(columns = {3:"Year",4:"Month",5:"Day"})
# Create Index to merge on
href1['Index'] = range(1, len(href1)+1)
href1.set_index('Index')
href1.head()
# Join to Original Dataframe 
df1 = df1.merge(href1, how = 'outer', on = 'Index' )
# Fix the year column due to inconsistent href links
df1['Year'] = df1.href.apply(lambda x: (re.findall(r"20[0-9]{2}", x)[0]))
df1['Date'] = pd.to_datetime(df1[['Year', 'Month', 'Day']])
df1.head()
# Out:
#                                                 href  \
# 0  /earnings/call-transcripts/2020/04/30/microsof...
# 1  /earnings/call-transcripts/2020/01/30/microsof...
# 2  /earnings/call-transcripts/2019/10/23/microsof...
# 3  /earnings/call-transcripts/2019/07/18/microsof...
# 4  /earnings/call-transcripts/2019/04/25/microsof...
#
#                                           Transcript Ticker  Index  Year  \
# 0  ["OperatorGreetings and welcome to the Microso...   msft      1  2020
# 1  ["OperatorWelcome to the Microsoft Fiscal Year...   msft      2  2020
# 2  ["OperatorWelcome to the Microsoft Fiscal Year...   msft      3  2019
# 3  ["OperatorWelcome to the Microsoft Fiscal Year...   msft      4  2019
# 4  ['Prepared Remarks:', 'Operator', 'Greetings, ...   msft      5  2019
#
#   Month Day       Date
# 0    04  30 2020-04-30
# 1    01  30 2020-01-30
# 2    10  23 2019-10-23
# 3    07  18 2019-07-18
# 4    04  25 2019-04-25

# %%
#Create column with date 1 week later for comparison of stock prices
df1['Date_1Week_Before'] = df1['Date'] + pd.DateOffset(days = -7)
df1['Date_1Week_After'] = df1['Date'] + pd.DateOffset(days = 7)

# %%
# Get Quarter

# Split existing href
href2 = href[6].str.split(r'-\d',n = 3, expand = True)
href3 = href2[0].str.split('-q', n = 4, expand = True)

# Rename and drop unnessecary columns
href3 = href3.rename(columns = {1:'Quarter'})
href3 = href3.drop(columns = [0,2])

# Create Index
href3['Index'] = range(1, len(href1)+1)
href3.set_index('Index')
href3.head()

# Merge to existing dataframe
df1 = df1.merge(href3, how = 'outer', on = 'Index')
df1.head()
# Out:
#                                                 href  \
# 0  /earnings/call-transcripts/2020/04/30/microsof...
# 1  /earnings/call-transcripts/2020/01/30/microsof...
# 2  /earnings/call-transcripts/2019/10/23/microsof...
# 3  /earnings/call-transcripts/2019/07/18/microsof...
# 4  /earnings/call-transcripts/2019/04/25/microsof...
#
#                                           Transcript Ticker  Index  Year  \
# 0  ["OperatorGreetings and welcome to the Microso...   msft      1  2020
# 1  ["OperatorWelcome to the Microsoft Fiscal Year...   msft      2  2020
# 2  ["OperatorWelcome to the Microsoft Fiscal Year...   msft      3  2019
# 3  ["OperatorWelcome to the Microsoft Fiscal Year...   msft      4  2019
# 4  ['Prepared Remarks:', 'Operator', 'Greetings, ...   msft      5  2019
#
#   Month Day       Date Date_1Week_Before Date_1Week_After Quarter
# 0    04  30 2020-04-30        2020-04-23       2020-05-07       3
# 1    01  30 2020-01-30        2020-01-23       2020-02-06       2
# 2    10  23 2019-10-23        2019-10-16       2019-10-30       1
# 3    07  18 2019-07-18        2019-07-11       2019-07-25       4
# 4    04  25 2019-04-25        2019-04-18       2019-05-02       3

# %%
#bootleg company name column
df1['CompanyName'] = df1['href'].str[38:]

# %%
df1.head()
# Out:
#                                                 href  \
# 0  /earnings/call-transcripts/2020/04/30/microsof...
# 1  /earnings/call-transcripts/2020/01/30/microsof...
# 2  /earnings/call-transcripts/2019/10/23/microsof...
# 3  /earnings/call-transcripts/2019/07/18/microsof...
# 4  /earnings/call-transcripts/2019/04/25/microsof...
#
#                                           Transcript Ticker  Index  Year  \
# 0  ["OperatorGreetings and welcome to the Microso...   msft      1  2020
# 1  ["OperatorWelcome to the Microsoft Fiscal Year...   msft      2  2020
# 2  ["OperatorWelcome to the Microsoft Fiscal Year...   msft      3  2019
# 3  ["OperatorWelcome to the Microsoft Fiscal Year...   msft      4  2019
# 4  ['Prepared Remarks:', 'Operator', 'Greetings, ...   msft      5  2019
#
#   Month Day       Date Date_1Week_Before Date_1Week_After Quarter  \
# 0    04  30 2020-04-30        2020-04-23       2020-05-07       3
# 1    01  30 2020-01-30        2020-01-23       2020-02-06       2
# 2    10  23 2019-10-23        2019-10-16       2019-10-30       1
# 3    07  18 2019-07-18        2019-07-11       2019-07-25       4
# 4    04  25 2019-04-25        2019-04-18       2019-05-02       3
#
#                                          CompanyName
# 0  microsoft-corp-msft-q3-2020-earnings-call-tran...
# 1  microsoft-corp-msft-q2-2020-earnings-call-tran...
# 2  microsoft-corp-msft-q1-2020-earnings-call-tran...
# 3  microsoft-corp-msft-q4-2019-earnings-call-tran...
# 4  microsoft-corp-msft-q3-2019-earnings-call-tran...

# %% [markdown]
# # Ryan's Sandbox

# %%
# Contraction dictionary
contractions_dict = {
    "didn't": 'did not',
    "don't": 'do not',
    "aren't": 'are not',
    "can't": 'cannot',
    "could've": "could've",
    "couldn't": "could not",
    "i'll": "i will",
    "i'd": "i would",
    "i'm": "i am",
    "it'll": "it will",
    "we'll": "we will"
    
}

contractions_re = re.compile('(%s)' % '|'.join(contractions_dict.keys()))

def expand_contractions(s, contractions_dict=contractions_dict):
    def replace(match):
        return contractions_dict[match.group(0)]
    return contractions_re.sub(replace, s)

# %%
# Standard function to clean string
def clean(string):
    x = string.lower() # lowercases the string
    x = expand_contractions(x) # replaces contractions
    x = re.sub(r'\W+', ' ', x) # takes only alpha numeric
    return x

# %%
stonks = pd.read_csv("/Users/Adam/Desktop/NLP/Company_Stock_Price_Clean.csv")

# %%
stonks.head(n=10)
# Out:
#          Date Ticker   Adj_Close
# 0  2017-01-03   MSFT   58.969059
# 1  2017-01-03   AAPL  110.392334
# 2  2017-01-03   AMZN  753.669983
# 3  2017-01-03     FB  116.860001
# 4  2017-01-03  GOOGL  808.010010
# 5  2017-01-03   GOOG  786.140015
# 6  2017-01-03    JNJ  105.502319
# 7  2017-01-03      V   77.675957
# 8  2017-01-03     PG   75.750793
# 9  2017-01-03    JPM   79.052376

# %%
stonks['Ticker'] = stonks['Ticker'].astype(str)
stonks['Ticker'] = stonks['Ticker'].str.lower()

# %%
df1['Date'] = pd.to_datetime(df1['Date'])
stonks['Date'] = pd.to_datetime(stonks['Date'])

# %%
#try to merge the 2 datasets
# but this needs the Ticker on the original dataset
df_final = pd.merge(df1, stonks, on = ['Date', 'Ticker'], how = 'inner')

# %%
df_final = pd.merge(df_final, stonks, left_on = ['Date_1Week_Before', 'Ticker'],
                                             right_on = ['Date', 'Ticker'], how = 'inner')

# %%
df_final = pd.merge(df_final, stonks, left_on = ['Date_1Week_After', 'Ticker'],
                                             right_on = ['Date', 'Ticker'], how = 'inner')

# %%
df_final.head()
# Out:
#                                                 href  \
# 0  /earnings/call-transcripts/2020/04/30/microsof...
# 1  /earnings/call-transcripts/2020/01/30/microsof...
# 2  /earnings/call-transcripts/2019/10/23/microsof...
# 3  /earnings/call-transcripts/2019/07/18/microsof...
# 4  /earnings/call-transcripts/2019/04/25/microsof...
#
#                                           Transcript Ticker  Index  Year  \
# 0  ["OperatorGreetings and welcome to the Microso...   msft      1  2020
# 1  ["OperatorWelcome to the Microsoft Fiscal Year...   msft      2  2020
# 2  ["OperatorWelcome to the Microsoft Fiscal Year...   msft      3  2019
# 3  ["OperatorWelcome to the Microsoft Fiscal Year...   msft      4  2019
# 4  ['Prepared Remarks:', 'Operator', 'Greetings, ...   msft      5  2019
#
#   Month Day     Date_x Date_1Week_Before Date_1Week_After Quarter  \
# 0    04  30 2020-04-30        2020-04-23       2020-05-07       3
# 1    01  30 2020-01-30        2020-01-23       2020-02-06       2
# 2    10  23 2019-10-23        2019-10-16       2019-10-30       1
# 3    07  18 2019-07-18        2019-07-11       2019-07-25       4
# 4    04  25 2019-04-25        2019-04-18       2019-05-02       3
#
#                                          CompanyName  Adj_Close_x     Date_y  \
# 0  microsoft-corp-msft-q3-2020-earnings-call-tran...   178.712280 2020-04-23
# 1  microsoft-corp-msft-q2-2020-earnings-call-tran...   171.830795 2020-01-23
# 2  microsoft-corp-msft-q1-2020-earnings-call-tran...   136.023209 2019-10-16
# 3  microsoft-corp-msft-q4-2019-earnings-call-tran...   134.761719 2019-07-11
# 4  microsoft-corp-msft-q3-2019-earnings-call-tran...   127.109573 2019-04-18
#
#    Adj_Close_y       Date   Adj_Close
# 0   170.943909 2020-05-07  183.090088
# 1   165.804092 2020-02-06  182.621201
# 2   139.165085 2019-10-30  143.327850
# 3   136.717636 2019-07-25  138.485886
# 4   121.420891 2019-05-02  124.216019

# %%
df_final = df_final.drop(columns = ['Date_y', 'Date'])

# %%
df_final = df_final.rename(columns = {'Adj_Close_y':'Price_Before', 'Adj_Close':'Price_After', 'Adj_Close_x': 'Adj_Close',
                               'Date_x':'Date'})

# %%
df_final.head(n=5)
# Out:
#                                                 href  \
# 0  /earnings/call-transcripts/2020/04/30/microsof...
# 1  /earnings/call-transcripts/2020/01/30/microsof...
# 2  /earnings/call-transcripts/2019/10/23/microsof...
# 3  /earnings/call-transcripts/2019/07/18/microsof...
# 4  /earnings/call-transcripts/2019/04/25/microsof...
#
#                                           Transcript Ticker  Index  Year  \
# 0  ["OperatorGreetings and welcome to the Microso...   msft      1  2020
# 1  ["OperatorWelcome to the Microsoft Fiscal Year...   msft      2  2020
# 2  ["OperatorWelcome to the Microsoft Fiscal Year...   msft      3  2019
# 3  ["OperatorWelcome to the Microsoft Fiscal Year...   msft      4  2019
# 4  ['Prepared Remarks:', 'Operator', 'Greetings, ...   msft      5  2019
#
#   Month Day       Date Date_1Week_Before Date_1Week_After Quarter  \
# 0    04  30 2020-04-30        2020-04-23       2020-05-07       3
# 1    01  30 2020-01-30        2020-01-23       2020-02-06       2
# 2    10  23 2019-10-23        2019-10-16       2019-10-30       1
# 3    07  18 2019-07-18        2019-07-11       2019-07-25       4
# 4    04  25 2019-04-25        2019-04-18       2019-05-02       3
#
#                                          CompanyName   Adj_Close  \
# 0  microsoft-corp-msft-q3-2020-earnings-call-tran...  178.712280
# 1  microsoft-corp-msft-q2-2020-earnings-call-tran...  171.830795
# 2  microsoft-corp-msft-q1-2020-earnings-call-tran...  136.023209
# 3  microsoft-corp-msft-q4-2019-earnings-call-tran...  134.761719
# 4  microsoft-corp-msft-q3-2019-earnings-call-tran...  127.109573
#
#    Price_Before  Price_After
# 0    170.943909   183.090088
# 1    165.804092   182.621201
# 2    139.165085   143.327850
# 3    136.717636   138.485886
# 4    121.420891   124.216019

# %%
df_final['clean_transcript'] = df_final.Transcript.apply(lambda x: clean(x))

# %%
# List of stopwords
stop = list(STOPWORDS)

# Functions
# removes stop words from a clean transcript
def remove_stop(string):
    wostop = [] # empty list to append to
    word = string.split() # splits string into list
    for n, i in enumerate(word): # iterates over the list
        if i not in stop: # if word in the list not in stop words list
            wostop.append(word[n]) # append to wostop list
    wostop = ' '.join(wostop) # join wostop list into a string
    return wostop # returns a string

# Stems word
def stem(string):
    t = [] # empty list to append
    ps = nltk.stem.PorterStemmer() # stem purposes
    word = string.split() # split string into list
    for item in word: # iterate through list
        stem = ps.stem(item) # stem each word
        t.append(stem) # add new stem word into list
    t = ' '.join(t) # join list of stem words into a string
    return t # returns a string

# %%
df_final['clean_transcript2'] = df_final.clean_transcript.apply(lambda x: remove_stop(x))
df_final.head()
# Out:
#                                                 href  \
# 0  /earnings/call-transcripts/2020/04/30/microsof...
# 1  /earnings/call-transcripts/2020/01/30/microsof...
# 2  /earnings/call-transcripts/2019/10/23/microsof...
# 3  /earnings/call-transcripts/2019/07/18/microsof...
# 4  /earnings/call-transcripts/2019/04/25/microsof...
#
#                                           Transcript Ticker  Index  Year  \
# 0  ["OperatorGreetings and welcome to the Microso...   msft      1  2020
# 1  ["OperatorWelcome to the Microsoft Fiscal Year...   msft      2  2020
# 2  ["OperatorWelcome to the Microsoft Fiscal Year...   msft      3  2019
# 3  ["OperatorWelcome to the Microsoft Fiscal Year...   msft      4  2019
# 4  ['Prepared Remarks:', 'Operator', 'Greetings, ...   msft      5  2019
#
#   Month Day       Date Date_1Week_Before Date_1Week_After Quarter  \
# 0    04  30 2020-04-30        2020-04-23       2020-05-07       3
# 1    01  30 2020-01-30        2020-01-23       2020-02-06       2
# 2    10  23 2019-10-23        2019-10-16       2019-10-30       1
# 3    07  18 2019-07-18        2019-07-11       2019-07-25       4
# 4    04  25 2019-04-25        2019-04-18       2019-05-02       3
#
#                                          CompanyName   Adj_Close  \
# 0  microsoft-corp-msft-q3-2020-earnings-call-tran...  178.712280
# 1  microsoft-corp-msft-q2-2020-earnings-call-tran...  171.830795
# 2  microsoft-corp-msft-q1-2020-earnings-call-tran...  136.023209
# 3  microsoft-corp-msft-q4-2019-earnings-call-tran...  134.761719
# 4  microsoft-corp-msft-q3-2019-earnings-call-tran...  127.109573
#
#    Price_Before  Price_After  \
# 0    170.943909   183.090088
# 1    165.804092   182.621201
# 2    139.165085   143.327850
# 3    136.717636   138.485886
# 4    121.420891   124.216019
#
#                                     clean_transcript  \
# 0   operatorgreetings and welcome to the microsof...
# 1   operatorwelcome to the microsoft fiscal year ...
# 2   operatorwelcome to the microsoft fiscal year ...
# 3   operatorwelcome to the microsoft fiscal year ...
# 4   prepared remarks operator greetings welcome t...
#
#                                    clean_transcript2
# 0  operatorgreetings welcome microsoft fiscal yea...
# 1  operatorwelcome microsoft fiscal year 2020 sec...
# 2  operatorwelcome microsoft fiscal year 2020 fir...
# 3  operatorwelcome microsoft fiscal year 2019 fou...
# 4  prepared remarks operator greetings welcome mi...

# %%
df_final = df_final.drop(columns = ['Index'])
df_final = df_final.drop(columns = ['clean_transcript'])

# %%
df_final = (df_final[df_final.Transcript.apply(lambda x: len(x) > 10)])
df_final
# Out:
#                                                    href  \
# 0     /earnings/call-transcripts/2020/04/30/microsof...
# 1     /earnings/call-transcripts/2020/01/30/microsof...
# 2     /earnings/call-transcripts/2019/10/23/microsof...
# 3     /earnings/call-transcripts/2019/07/18/microsof...
# 4     /earnings/call-transcripts/2019/04/25/microsof...
# ...                                                 ...
# 3227  /earnings/call-transcripts/2019/11/06/coty-inc...
# 3228  /earnings/call-transcripts/2019/08/28/coty-inc...
# 3230  /earnings/call-transcripts/2019/02/08/coty-inc...
# 3231  /earnings/call-transcripts/2018/11/07/coty-inc...
# 3232  /earnings/call-transcripts/2018/08/21/coty-inc...
#
#                                              Transcript Ticker  Year Month  \
# 0     ["OperatorGreetings and welcome to the Microso...   msft  2020    04
# 1     ["OperatorWelcome to the Microsoft Fiscal Year...   msft  2020    01
# 2     ["OperatorWelcome to the Microsoft Fiscal Year...   msft  2019    10
# 3     ["OperatorWelcome to the Microsoft Fiscal Year...   msft  2019    07
# 4     ['Prepared Remarks:', 'Operator', 'Greetings, ...   msft  2019    04
# ...                                                 ...    ...   ...   ...
# 3227  ["OperatorGood morning, ladies and gentlemen. ...   coty  2019    11
# 3228  ["OperatorGood morning, ladies and gentlemen. ...   coty  2019    08
# 3230  ['Contents:', '', 'Prepared Remarks', 'Questio...   coty  2019    02
# 3231  ['Prepared Remarks:', 'Operator', "Good mornin...   coty  2018    11
# 3232  ['Prepared Remarks:', 'Operator', "Good mornin...   coty  2018    08
#
#      Day       Date Date_1Week_Before Date_1Week_After Quarter  \
# 0     30 2020-04-30        2020-04-23       2020-05-07       3
# 1     30 2020-01-30        2020-01-23       2020-02-06       2
# 2     23 2019-10-23        2019-10-16       2019-10-30       1
# 3     18 2019-07-18        2019-07-11       2019-07-25       4
# 4     25 2019-04-25        2019-04-18       2019-05-02       3
# ...   ..        ...               ...              ...     ...
# 3227  06 2019-11-06        2019-10-30       2019-11-13       1
# 3228  28 2019-08-28        2019-08-21       2019-09-04       4
# 3230  08 2019-02-08        2019-02-01       2019-02-15       2
# 3231  07 2018-11-07        2018-10-31       2018-11-14       1
# 3232  21 2018-08-21        2018-08-14       2018-08-28       4
#
#                                             CompanyName   Adj_Close  \
# 0     microsoft-corp-msft-q3-2020-earnings-call-tran...  178.712280
# 1     microsoft-corp-msft-q2-2020-earnings-call-tran...  171.830795
# 2     microsoft-corp-msft-q1-2020-earnings-call-tran...  136.023209
# 3     microsoft-corp-msft-q4-2019-earnings-call-tran...  134.761719
# 4     microsoft-corp-msft-q3-2019-earnings-call-tran...  127.109573
# ...                                                 ...         ...
# 3227     coty-inc-coty-q1-2020-earnings-call-transcript   12.747121
# 3228     coty-inc-coty-q4-2019-earnings-call-transcript    9.019238
# 3230  coty-inc-coty-q2-2019-earnings-conference-call...    8.832841
# 3231  coty-inc-coty-q1-2019-earnings-conference-call...    8.078259
# 3232  coty-inc-coty-q4-2019-earnings-conference-call...   10.642809
#
#       Price_Before  Price_After  \
# 0       170.943909   183.090088
# 1       165.804092   182.621201
# 2       139.165085   143.327850
# 3       136.717636   138.485886
# 4       121.420891   124.216019
# ...            ...          ...
# 3227     11.386252    11.983468
# 3228      8.555227     9.077241
# 3230      7.138223    10.451722
# 3231      9.841298     8.115572
# 3232     10.873773    11.742196
#
#                                       clean_transcript2
# 0     operatorgreetings welcome microsoft fiscal yea...
# 1     operatorwelcome microsoft fiscal year 2020 sec...
# 2     operatorwelcome microsoft fiscal year 2020 fir...
# 3     operatorwelcome microsoft fiscal year 2019 fou...
# 4     prepared remarks operator greetings welcome mi...
# ...                                                 ...
# 3227  operatorgood morning ladies gentlemen name mar...
# 3228  operatorgood morning ladies gentlemen name mar...
# 3230  contents prepared remarks questions answers ca...
# 3231  prepared remarks operator good morning ladies ...
# 3232  prepared remarks operator good morning ladies ...
#
# [2896 rows x 15 columns]

# %%
#df_final.to_csv('Transcripts_Clean.csv')
