# %%
# Standard
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re
import warnings; warnings.simplefilter('ignore')
from dfply import * # dplyr equivalent
import datetime

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %% [markdown]
# # Cleaning Transcripts

# %%
df1 = pd.read_csv(r"C:\Users\Ryan\Documents\GitHub\NLP_Final_Project\earning_calls.csv")
df1.head(n=10)

# Set index
df1['Index'] = range(1, len(df1)+1)
df1.set_index('Index')
# Out:
#                                                     href  \
# Index
# 1      /earnings/call-transcripts/2020/04/30/microsof...
# 2      /earnings/call-transcripts/2020/01/30/microsof...
# 3      /earnings/call-transcripts/2019/10/23/microsof...
# 4      /earnings/call-transcripts/2019/07/18/microsof...
# 5      /earnings/call-transcripts/2019/04/25/microsof...
# ...                                                  ...
# 3491   /earnings/call-transcripts/2019/08/28/coty-inc...
# 3492   /earnings/call-transcripts/2019/05/08/coty-inc...
# 3493   /earnings/call-transcripts/2019/02/08/coty-inc...
# 3494   /earnings/call-transcripts/2018/11/07/coty-inc...
# 3495   /earnings/call-transcripts/2018/08/21/coty-inc...
#
#                                               Transcript Ticker
# Index
# 1      ["OperatorGreetings and welcome to the Microso...   msft
# 2      ["OperatorWelcome to the Microsoft Fiscal Year...   msft
# 3      ["OperatorWelcome to the Microsoft Fiscal Year...   msft
# 4      ["OperatorWelcome to the Microsoft Fiscal Year...   msft
# 5      ['Prepared Remarks:', 'Operator', 'Greetings, ...   msft
# ...                                                  ...    ...
# 3491   ["OperatorGood morning, ladies and gentlemen. ...   coty
# 3492                                                  []   coty
# 3493   ['Contents:', '', 'Prepared Remarks', 'Questio...   coty
# 3494   ['Prepared Remarks:', 'Operator', "Good mornin...   coty
# 3495   ['Prepared Remarks:', 'Operator', "Good mornin...   coty
#
# [3495 rows x 3 columns]

# %%
# Get Date

# Split href
href = df1['href'].str.split("/",n=6,expand=True)

# Drop unnecessary axes
href1 = href.drop([0,1,2,6], axis = 1)

# Rename Axes
href1 = href1.rename(columns = {3:"Year",4:"Month",5:"Day"})

# Create Index to merge on
href1['Index'] = range(1, len(href1)+1)
href1.set_index('Index')
href1.head()

# Join to Original Dataframe 
df1 = df1.merge(href1, how = 'outer', on = 'Index' )

# Fix the year column due to inconsistent href links
df1['Year'] = df1.href.apply(lambda x: (re.findall(r"20[0-9]{2}", x)[0]))

# Create date column
df1['Date'] = pd.to_datetime(df1[['Year', 'Month', 'Day']])

df1.head()
# Out:
#                                                 href  \
# 0  /earnings/call-transcripts/2020/04/30/microsof...
# 1  /earnings/call-transcripts/2020/01/30/microsof...
# 2  /earnings/call-transcripts/2019/10/23/microsof...
# 3  /earnings/call-transcripts/2019/07/18/microsof...
# 4  /earnings/call-transcripts/2019/04/25/microsof...
#
#                                           Transcript Ticker  Index  Year  \
# 0  ["OperatorGreetings and welcome to the Microso...   msft      1  2020
# 1  ["OperatorWelcome to the Microsoft Fiscal Year...   msft      2  2020
# 2  ["OperatorWelcome to the Microsoft Fiscal Year...   msft      3  2019
# 3  ["OperatorWelcome to the Microsoft Fiscal Year...   msft      4  2019
# 4  ['Prepared Remarks:', 'Operator', 'Greetings, ...   msft      5  2019
#
#   Month Day       Date
# 0    04  30 2020-04-30
# 1    01  30 2020-01-30
# 2    10  23 2019-10-23
# 3    07  18 2019-07-18
# 4    04  25 2019-04-25

# %%
# Get Quarter

# Split existing href
href2 = href[6].str.split(r'-\d',n = 3, expand = True)
href3 = href2[0].str.split('-q', n = 4, expand = True)

# Rename and drop unnessecary columns
href3 = href3.rename(columns = {1:'Quarter'})
href3 = href3.drop(columns = [0,2])

# Create Index
href3['Index'] = range(1, len(href1)+1)
href3.set_index('Index')
href3.head()

# Merge to existing dataframe
df1 = df1.merge(href3, how = 'outer', on = 'Index')
df1.head()
# Out:
#                                                 href  \
# 0  /earnings/call-transcripts/2020/04/30/microsof...
# 1  /earnings/call-transcripts/2020/01/30/microsof...
# 2  /earnings/call-transcripts/2019/10/23/microsof...
# 3  /earnings/call-transcripts/2019/07/18/microsof...
# 4  /earnings/call-transcripts/2019/04/25/microsof...
#
#                                           Transcript Ticker  Index  Year  \
# 0  ["OperatorGreetings and welcome to the Microso...   msft      1  2020
# 1  ["OperatorWelcome to the Microsoft Fiscal Year...   msft      2  2020
# 2  ["OperatorWelcome to the Microsoft Fiscal Year...   msft      3  2019
# 3  ["OperatorWelcome to the Microsoft Fiscal Year...   msft      4  2019
# 4  ['Prepared Remarks:', 'Operator', 'Greetings, ...   msft      5  2019
#
#   Month Day       Date Quarter
# 0    04  30 2020-04-30       3
# 1    01  30 2020-01-30       2
# 2    10  23 2019-10-23       1
# 3    07  18 2019-07-18       4
# 4    04  25 2019-04-25       3

# %%
#bootleg company name column
df1['CompanyName'] = df1['href'].str[38:]

# %%
# Reorder column names

cols = df1.columns.tolist()
myorder = [7,0,5,6,1,3,4,2]
cols = [cols[i] for i in myorder]
df1 = df1[cols]

# %%
df1.head()
# Out:
#         Date                                               href Month Day  \
# 0 2020-04-30  /earnings/call-transcripts/2020/04/30/microsof...    04  30
# 1 2020-01-30  /earnings/call-transcripts/2020/01/30/microsof...    01  30
# 2 2019-10-23  /earnings/call-transcripts/2019/10/23/microsof...    10  23
# 3 2019-07-18  /earnings/call-transcripts/2019/07/18/microsof...    07  18
# 4 2019-04-25  /earnings/call-transcripts/2019/04/25/microsof...    04  25
#
#                                           Transcript  Index  Year Ticker
# 0  ["OperatorGreetings and welcome to the Microso...      1  2020   msft
# 1  ["OperatorWelcome to the Microsoft Fiscal Year...      2  2020   msft
# 2  ["OperatorWelcome to the Microsoft Fiscal Year...      3  2019   msft
# 3  ["OperatorWelcome to the Microsoft Fiscal Year...      4  2019   msft
# 4  ['Prepared Remarks:', 'Operator', 'Greetings, ...      5  2019   msft

# %%
# Contraction dictionary
contractions_dict = {
    "didn't": 'did not',
    "don't": 'do not',
    "aren't": 'are not',
    "can't": 'cannot',
    "could've": "could've",
    "couldn't": "could not",
    "i'll": "i will",
    "i'd": "i would",
    "i'm": "i am",
    "it'll": "it will",
    "we'll": "we will"
    
}

contractions_re = re.compile('(%s)' % '|'.join(contractions_dict.keys()))

def expand_contractions(s, contractions_dict=contractions_dict):
    def replace(match):
        return contractions_dict[match.group(0)]
    return contractions_re.sub(replace, s)

# %%
expand_contractions(r"couldn't")
# Out:
# 'could not'

# %%
# Standard function to clean string
def clean(string):
    x = string.lower() # lowercases the string
    x = expand_contractions(x) # replaces contractions
    x = re.sub(r'\W+', ' ', x) # takes only alpha numeric
    return x

# %%
df1['clean_transcript'] = df1.Transcript.apply(lambda x: clean(x))

# %%
df1.head()
# Out:
#         Date                                               href Month Day  \
# 0 2020-04-30  /earnings/call-transcripts/2020/04/30/microsof...    04  30
# 1 2020-01-30  /earnings/call-transcripts/2020/01/30/microsof...    01  30
# 2 2019-10-23  /earnings/call-transcripts/2019/10/23/microsof...    10  23
# 3 2019-07-18  /earnings/call-transcripts/2019/07/18/microsof...    07  18
# 4 2019-04-25  /earnings/call-transcripts/2019/04/25/microsof...    04  25
#
#                                           Transcript  Index  Year Ticker  \
# 0  ["OperatorGreetings and welcome to the Microso...      1  2020   msft
# 1  ["OperatorWelcome to the Microsoft Fiscal Year...      2  2020   msft
# 2  ["OperatorWelcome to the Microsoft Fiscal Year...      3  2019   msft
# 3  ["OperatorWelcome to the Microsoft Fiscal Year...      4  2019   msft
# 4  ['Prepared Remarks:', 'Operator', 'Greetings, ...      5  2019   msft
#
#                                     clean_transcript
# 0   operatorgreetings and welcome to the microsof...
# 1   operatorwelcome to the microsoft fiscal year ...
# 2   operatorwelcome to the microsoft fiscal year ...
# 3   operatorwelcome to the microsoft fiscal year ...
# 4   prepared remarks operator greetings welcome t...

# %%
# List of stopwords
stop = list(STOPWORDS)

# Functions
# removes stop words from a clean transcript
def remove_stop(string):
    wostop = [] # empty list to append to
    word = string.split() # splits string into list
    for n, i in enumerate(word): # iterates over the list
        if i not in stop: # if word in the list not in stop words list
            wostop.append(word[n]) # append to wostop list
    wostop = ' '.join(wostop) # join wostop list into a string
    return wostop # returns a string

# Stems word
def stem(string):
    t = [] # empty list to append
    ps = nltk.stem.PorterStemmer() # stem purposes
    word = string.split() # split string into list
    for item in word: # iterate through list
        stem = ps.stem(item) # stem each word
        t.append(stem) # add new stem word into list
    t = ' '.join(t) # join list of stem words into a string
    return t # returns a string

# %%
# Remove stop words
df1['clean_transcript2'] = df1.clean_transcript.apply(lambda x: remove_stop(x))
df1
# Out:
#            Date                                               href Month Day  \
# 0    2020-04-30  /earnings/call-transcripts/2020/04/30/microsof...    04  30
# 1    2020-01-30  /earnings/call-transcripts/2020/01/30/microsof...    01  30
# 2    2019-10-23  /earnings/call-transcripts/2019/10/23/microsof...    10  23
# 3    2019-07-18  /earnings/call-transcripts/2019/07/18/microsof...    07  18
# 4    2019-04-25  /earnings/call-transcripts/2019/04/25/microsof...    04  25
# ...         ...                                                ...   ...  ..
# 3490 2019-08-28  /earnings/call-transcripts/2019/08/28/coty-inc...    08  28
# 3491 2019-05-08  /earnings/call-transcripts/2019/05/08/coty-inc...    05  08
# 3492 2019-02-08  /earnings/call-transcripts/2019/02/08/coty-inc...    02  08
# 3493 2018-11-07  /earnings/call-transcripts/2018/11/07/coty-inc...    11  07
# 3494 2018-08-21  /earnings/call-transcripts/2018/08/21/coty-inc...    08  21
#
#                                              Transcript  Index  Year Ticker  \
# 0     ["OperatorGreetings and welcome to the Microso...      1  2020   msft
# 1     ["OperatorWelcome to the Microsoft Fiscal Year...      2  2020   msft
# 2     ["OperatorWelcome to the Microsoft Fiscal Year...      3  2019   msft
# 3     ["OperatorWelcome to the Microsoft Fiscal Year...      4  2019   msft
# 4     ['Prepared Remarks:', 'Operator', 'Greetings, ...      5  2019   msft
# ...                                                 ...    ...   ...    ...
# 3490  ["OperatorGood morning, ladies and gentlemen. ...   3491  2019   coty
# 3491                                                 []   3492  2019   coty
# 3492  ['Contents:', '', 'Prepared Remarks', 'Questio...   3493  2019   coty
# 3493  ['Prepared Remarks:', 'Operator', "Good mornin...   3494  2018   coty
# 3494  ['Prepared Remarks:', 'Operator', "Good mornin...   3495  2018   coty
#
#                                        clean_transcript  \
# 0      operatorgreetings and welcome to the microsof...
# 1      operatorwelcome to the microsoft fiscal year ...
# 2      operatorwelcome to the microsoft fiscal year ...
# 3      operatorwelcome to the microsoft fiscal year ...
# 4      prepared remarks operator greetings welcome t...
# ...                                                 ...
# 3490   operatorgood morning ladies and gentlemen my ...
# 3491
# 3492   contents prepared remarks questions and answe...
# 3493   prepared remarks operator good morning ladies...
# 3494   prepared remarks operator good morning ladies...
#
#                                       clean_transcript2
# 0     operatorgreetings welcome microsoft fiscal yea...
# 1     operatorwelcome microsoft fiscal year 2020 sec...
# 2     operatorwelcome microsoft fiscal year 2020 fir...
# 3     operatorwelcome microsoft fiscal year 2019 fou...
# 4     prepared remarks operator greetings welcome mi...
# ...                                                 ...
# 3490  operatorgood morning ladies gentlemen name mar...
# 3491
# 3492  contents prepared remarks questions answers ca...
# 3493  prepared remarks operator good morning ladies ...
# 3494  prepared remarks operator good morning ladies ...
#
# [3495 rows x 10 columns]

# %%
# final dataframe without empty transcript
df2 = (df1[df1.Transcript.apply(lambda x: len(x) > 10)])
df2
# Out:
#            Date                                               href Month Day  \
# 0    2020-04-30  /earnings/call-transcripts/2020/04/30/microsof...    04  30
# 1    2020-01-30  /earnings/call-transcripts/2020/01/30/microsof...    01  30
# 2    2019-10-23  /earnings/call-transcripts/2019/10/23/microsof...    10  23
# 3    2019-07-18  /earnings/call-transcripts/2019/07/18/microsof...    07  18
# 4    2019-04-25  /earnings/call-transcripts/2019/04/25/microsof...    04  25
# ...         ...                                                ...   ...  ..
# 3489 2019-11-06  /earnings/call-transcripts/2019/11/06/coty-inc...    11  06
# 3490 2019-08-28  /earnings/call-transcripts/2019/08/28/coty-inc...    08  28
# 3492 2019-02-08  /earnings/call-transcripts/2019/02/08/coty-inc...    02  08
# 3493 2018-11-07  /earnings/call-transcripts/2018/11/07/coty-inc...    11  07
# 3494 2018-08-21  /earnings/call-transcripts/2018/08/21/coty-inc...    08  21
#
#                                              Transcript  Index  Year Ticker  \
# 0     ["OperatorGreetings and welcome to the Microso...      1  2020   msft
# 1     ["OperatorWelcome to the Microsoft Fiscal Year...      2  2020   msft
# 2     ["OperatorWelcome to the Microsoft Fiscal Year...      3  2019   msft
# 3     ["OperatorWelcome to the Microsoft Fiscal Year...      4  2019   msft
# 4     ['Prepared Remarks:', 'Operator', 'Greetings, ...      5  2019   msft
# ...                                                 ...    ...   ...    ...
# 3489  ["OperatorGood morning, ladies and gentlemen. ...   3490  2019   coty
# 3490  ["OperatorGood morning, ladies and gentlemen. ...   3491  2019   coty
# 3492  ['Contents:', '', 'Prepared Remarks', 'Questio...   3493  2019   coty
# 3493  ['Prepared Remarks:', 'Operator', "Good mornin...   3494  2018   coty
# 3494  ['Prepared Remarks:', 'Operator', "Good mornin...   3495  2018   coty
#
#                                        clean_transcript  \
# 0      operatorgreetings and welcome to the microsof...
# 1      operatorwelcome to the microsoft fiscal year ...
# 2      operatorwelcome to the microsoft fiscal year ...
# 3      operatorwelcome to the microsoft fiscal year ...
# 4      prepared remarks operator greetings welcome t...
# ...                                                 ...
# 3489   operatorgood morning ladies and gentlemen my ...
# 3490   operatorgood morning ladies and gentlemen my ...
# 3492   contents prepared remarks questions and answe...
# 3493   prepared remarks operator good morning ladies...
# 3494   prepared remarks operator good morning ladies...
#
#                                       clean_transcript2
# 0     operatorgreetings welcome microsoft fiscal yea...
# 1     operatorwelcome microsoft fiscal year 2020 sec...
# 2     operatorwelcome microsoft fiscal year 2020 fir...
# 3     operatorwelcome microsoft fiscal year 2019 fou...
# 4     prepared remarks operator greetings welcome mi...
# ...                                                 ...
# 3489  operatorgood morning ladies gentlemen name mar...
# 3490  operatorgood morning ladies gentlemen name mar...
# 3492  contents prepared remarks questions answers ca...
# 3493  prepared remarks operator good morning ladies ...
# 3494  prepared remarks operator good morning ladies ...
#
# [3129 rows x 10 columns]

# %% [markdown]
# # Merging Stock onto Transcript

# %%
# Function to use later
# Find the next available date
def next(x):
    if x.weekday() == 5: # If next day is saturday, return next monday
        return x + pd.to_timedelta(2, unit = "D")
    elif x.weekday() == 6: # If next day is sunday, return next monday
        return x + pd.to_timedelta(1, unit = "D")
    else:
        return x # If its weekday, return same date

# %%
# Read stock data cleaned through alteryx
stonks = pd.read_csv(r"C:\Users\Ryan\Documents\GitHub\NLP_Final_Project\data\Company_Stock_Price_Clean.csv")
stonks.head()
# Out:
#          Date Ticker   Adj_Close
# 0  2017-01-03   MSFT   58.969059
# 1  2017-01-03   AAPL  110.392334
# 2  2017-01-03   AMZN  753.669983
# 3  2017-01-03     FB  116.860001
# 4  2017-01-03  GOOGL  808.010010

# %%
stonks.Ticker = stonks.Ticker.apply(lambda x: x.lower()) # lowercase tickers
stonks.Date = pd.to_datetime(stonks.Date) # Change to dateformat
stonks.head()
# Out:
#         Date Ticker   Adj_Close
# 0 2017-01-03   msft   58.969059
# 1 2017-01-03   aapl  110.392334
# 2 2017-01-03   amzn  753.669983
# 3 2017-01-03     fb  116.860001
# 4 2017-01-03  googl  808.010010

# %%
# Create next available day : date + 1 day
df2['Next_Available_Day'] = pd.to_datetime(df2.Date)+pd.to_timedelta(1, unit = "D")

# If Next Available day is on a weekend, set it to next monday
df2.Next_Available_Day = df2.Next_Available_Day.apply(lambda x: next(x))
df2
# Out:
#            Date                                               href Month Day  \
# 0    2020-04-30  /earnings/call-transcripts/2020/04/30/microsof...    04  30
# 1    2020-01-30  /earnings/call-transcripts/2020/01/30/microsof...    01  30
# 2    2019-10-23  /earnings/call-transcripts/2019/10/23/microsof...    10  23
# 3    2019-07-18  /earnings/call-transcripts/2019/07/18/microsof...    07  18
# 4    2019-04-25  /earnings/call-transcripts/2019/04/25/microsof...    04  25
# ...         ...                                                ...   ...  ..
# 3489 2019-11-06  /earnings/call-transcripts/2019/11/06/coty-inc...    11  06
# 3490 2019-08-28  /earnings/call-transcripts/2019/08/28/coty-inc...    08  28
# 3492 2019-02-08  /earnings/call-transcripts/2019/02/08/coty-inc...    02  08
# 3493 2018-11-07  /earnings/call-transcripts/2018/11/07/coty-inc...    11  07
# 3494 2018-08-21  /earnings/call-transcripts/2018/08/21/coty-inc...    08  21
#
#                                              Transcript  Index  Year Ticker  \
# 0     ["OperatorGreetings and welcome to the Microso...      1  2020   msft
# 1     ["OperatorWelcome to the Microsoft Fiscal Year...      2  2020   msft
# 2     ["OperatorWelcome to the Microsoft Fiscal Year...      3  2019   msft
# 3     ["OperatorWelcome to the Microsoft Fiscal Year...      4  2019   msft
# 4     ['Prepared Remarks:', 'Operator', 'Greetings, ...      5  2019   msft
# ...                                                 ...    ...   ...    ...
# 3489  ["OperatorGood morning, ladies and gentlemen. ...   3490  2019   coty
# 3490  ["OperatorGood morning, ladies and gentlemen. ...   3491  2019   coty
# 3492  ['Contents:', '', 'Prepared Remarks', 'Questio...   3493  2019   coty
# 3493  ['Prepared Remarks:', 'Operator', "Good mornin...   3494  2018   coty
# 3494  ['Prepared Remarks:', 'Operator', "Good mornin...   3495  2018   coty
#
#                                        clean_transcript  \
# 0      operatorgreetings and welcome to the microsof...
# 1      operatorwelcome to the microsoft fiscal year ...
# 2      operatorwelcome to the microsoft fiscal year ...
# 3      operatorwelcome to the microsoft fiscal year ...
# 4      prepared remarks operator greetings welcome t...
# ...                                                 ...
# 3489   operatorgood morning ladies and gentlemen my ...
# 3490   operatorgood morning ladies and gentlemen my ...
# 3492   contents prepared remarks questions and answe...
# 3493   prepared remarks operator good morning ladies...
# 3494   prepared remarks operator good morning ladies...
#
#                                       clean_transcript2 Next_Available_Day
# 0     operatorgreetings welcome microsoft fiscal yea...         2020-05-01
# 1     operatorwelcome microsoft fiscal year 2020 sec...         2020-01-31
# 2     operatorwelcome microsoft fiscal year 2020 fir...         2019-10-24
# 3     operatorwelcome microsoft fiscal year 2019 fou...         2019-07-19
# 4     prepared remarks operator greetings welcome mi...         2019-04-26
# ...                                                 ...                ...
# 3489  operatorgood morning ladies gentlemen name mar...         2019-11-07
# 3490  operatorgood morning ladies gentlemen name mar...         2019-08-29
# 3492  contents prepared remarks questions answers ca...         2019-02-11
# 3493  prepared remarks operator good morning ladies ...         2018-11-08
# 3494  prepared remarks operator good morning ladies ...         2018-08-22
#
# [3129 rows x 11 columns]

# %%
# Merge Stock and Transcript
merge_df = pd.merge(df2, stonks, on = ['Date', 'Ticker'], how = 'inner')
merge_df = merge_df.rename(columns={'Adj_Close': 'Date_Adj_Close'}) # Rename
merge_df.head()
# Out:
#         Date                                               href Month Day  \
# 0 2020-04-30  /earnings/call-transcripts/2020/04/30/microsof...    04  30
# 1 2020-01-30  /earnings/call-transcripts/2020/01/30/microsof...    01  30
# 2 2019-10-23  /earnings/call-transcripts/2019/10/23/microsof...    10  23
# 3 2019-07-18  /earnings/call-transcripts/2019/07/18/microsof...    07  18
# 4 2019-04-25  /earnings/call-transcripts/2019/04/25/microsof...    04  25
#
#                                           Transcript  Index  Year Ticker  \
# 0  ["OperatorGreetings and welcome to the Microso...      1  2020   msft
# 1  ["OperatorWelcome to the Microsoft Fiscal Year...      2  2020   msft
# 2  ["OperatorWelcome to the Microsoft Fiscal Year...      3  2019   msft
# 3  ["OperatorWelcome to the Microsoft Fiscal Year...      4  2019   msft
# 4  ['Prepared Remarks:', 'Operator', 'Greetings, ...      5  2019   msft
#
#                                     clean_transcript  \
# 0   operatorgreetings and welcome to the microsof...
# 1   operatorwelcome to the microsoft fiscal year ...
# 2   operatorwelcome to the microsoft fiscal year ...
# 3   operatorwelcome to the microsoft fiscal year ...
# 4   prepared remarks operator greetings welcome t...
#
#                                    clean_transcript2 Next_Available_Day  \
# 0  operatorgreetings welcome microsoft fiscal yea...         2020-05-01
# 1  operatorwelcome microsoft fiscal year 2020 sec...         2020-01-31
# 2  operatorwelcome microsoft fiscal year 2020 fir...         2019-10-24
# 3  operatorwelcome microsoft fiscal year 2019 fou...         2019-07-19
# 4  prepared remarks operator greetings welcome mi...         2019-04-26
#
#    Date_Adj_Close
# 0      178.712280
# 1      171.830795
# 2      136.023209
# 3      134.761719
# 4      127.109573

# %%
# create a duplicate stocks file. 
temp = stonks
temp = temp.rename(columns={'Date': 'Next_Available_Day'}) # Rename the date column to 1_day_after to match the mergedf

# Merge the temp table with the already merged dataframe
final = pd.merge(merge_df, temp, on = ['Next_Available_Day', 'Ticker'], how = 'inner')
final = final.rename(columns={'Adj_Close': 'Next_Available_Day_Adj_Close'})
final
# Out:
#            Date                                               href Month Day  \
# 0    2020-04-30  /earnings/call-transcripts/2020/04/30/microsof...    04  30
# 1    2020-01-30  /earnings/call-transcripts/2020/01/30/microsof...    01  30
# 2    2019-10-23  /earnings/call-transcripts/2019/10/23/microsof...    10  23
# 3    2019-07-18  /earnings/call-transcripts/2019/07/18/microsof...    07  18
# 4    2019-04-25  /earnings/call-transcripts/2019/04/25/microsof...    04  25
# ...         ...                                                ...   ...  ..
# 2987 2019-11-06  /earnings/call-transcripts/2019/11/06/coty-inc...    11  06
# 2988 2019-08-28  /earnings/call-transcripts/2019/08/28/coty-inc...    08  28
# 2989 2019-02-08  /earnings/call-transcripts/2019/02/08/coty-inc...    02  08
# 2990 2018-11-07  /earnings/call-transcripts/2018/11/07/coty-inc...    11  07
# 2991 2018-08-21  /earnings/call-transcripts/2018/08/21/coty-inc...    08  21
#
#                                              Transcript  Index  Year Ticker  \
# 0     ["OperatorGreetings and welcome to the Microso...      1  2020   msft
# 1     ["OperatorWelcome to the Microsoft Fiscal Year...      2  2020   msft
# 2     ["OperatorWelcome to the Microsoft Fiscal Year...      3  2019   msft
# 3     ["OperatorWelcome to the Microsoft Fiscal Year...      4  2019   msft
# 4     ['Prepared Remarks:', 'Operator', 'Greetings, ...      5  2019   msft
# ...                                                 ...    ...   ...    ...
# 2987  ["OperatorGood morning, ladies and gentlemen. ...   3490  2019   coty
# 2988  ["OperatorGood morning, ladies and gentlemen. ...   3491  2019   coty
# 2989  ['Contents:', '', 'Prepared Remarks', 'Questio...   3493  2019   coty
# 2990  ['Prepared Remarks:', 'Operator', "Good mornin...   3494  2018   coty
# 2991  ['Prepared Remarks:', 'Operator', "Good mornin...   3495  2018   coty
#
#                                        clean_transcript  \
# 0      operatorgreetings and welcome to the microsof...
# 1      operatorwelcome to the microsoft fiscal year ...
# 2      operatorwelcome to the microsoft fiscal year ...
# 3      operatorwelcome to the microsoft fiscal year ...
# 4      prepared remarks operator greetings welcome t...
# ...                                                 ...
# 2987   operatorgood morning ladies and gentlemen my ...
# 2988   operatorgood morning ladies and gentlemen my ...
# 2989   contents prepared remarks questions and answe...
# 2990   prepared remarks operator good morning ladies...
# 2991   prepared remarks operator good morning ladies...
#
#                                       clean_transcript2 Next_Available_Day  \
# 0     operatorgreetings welcome microsoft fiscal yea...         2020-05-01
# 1     operatorwelcome microsoft fiscal year 2020 sec...         2020-01-31
# 2     operatorwelcome microsoft fiscal year 2020 fir...         2019-10-24
# 3     operatorwelcome microsoft fiscal year 2019 fou...         2019-07-19
# 4     prepared remarks operator greetings welcome mi...         2019-04-26
# ...                                                 ...                ...
# 2987  operatorgood morning ladies gentlemen name mar...         2019-11-07
# 2988  operatorgood morning ladies gentlemen name mar...         2019-08-29
# 2989  contents prepared remarks questions answers ca...         2019-02-11
# 2990  prepared remarks operator good morning ladies ...         2018-11-08
# 2991  prepared remarks operator good morning ladies ...         2018-08-22
#
#       Date_Adj_Close  Next_Available_Day_Adj_Close
# 0         178.712280                    174.085175
# 1         171.830795                    169.294800
# 2         136.023209                    138.699264
# 3         134.761719                    134.959274
# 4         127.109573                    127.837875
# ...              ...                           ...
# 2987       12.747121                     12.727539
# 2988        9.019238                      9.038573
# 2989        8.832841                      9.145256
# 2990        8.078259                      7.742442
# 2991       10.642809                     10.827580
#
# [2992 rows x 13 columns]

# %%
# Percent change
final['Percent Change'] = ((final.Next_Available_Day_Adj_Close - final.Date_Adj_Close)/ final.Date_Adj_Close)*100

# If percent change is positive, label 1, if percent change is negative, label 0
final['Label'] = np.where(final.Next_Available_Day_Adj_Close > final.Date_Adj_Close, 1, 0)
final
# Out:
#            Date                                               href Month Day  \
# 0    2020-04-30  /earnings/call-transcripts/2020/04/30/microsof...    04  30
# 1    2020-01-30  /earnings/call-transcripts/2020/01/30/microsof...    01  30
# 2    2019-10-23  /earnings/call-transcripts/2019/10/23/microsof...    10  23
# 3    2019-07-18  /earnings/call-transcripts/2019/07/18/microsof...    07  18
# 4    2019-04-25  /earnings/call-transcripts/2019/04/25/microsof...    04  25
# ...         ...                                                ...   ...  ..
# 2987 2019-11-06  /earnings/call-transcripts/2019/11/06/coty-inc...    11  06
# 2988 2019-08-28  /earnings/call-transcripts/2019/08/28/coty-inc...    08  28
# 2989 2019-02-08  /earnings/call-transcripts/2019/02/08/coty-inc...    02  08
# 2990 2018-11-07  /earnings/call-transcripts/2018/11/07/coty-inc...    11  07
# 2991 2018-08-21  /earnings/call-transcripts/2018/08/21/coty-inc...    08  21
#
#                                              Transcript  Index  Year Ticker  \
# 0     ["OperatorGreetings and welcome to the Microso...      1  2020   msft
# 1     ["OperatorWelcome to the Microsoft Fiscal Year...      2  2020   msft
# 2     ["OperatorWelcome to the Microsoft Fiscal Year...      3  2019   msft
# 3     ["OperatorWelcome to the Microsoft Fiscal Year...      4  2019   msft
# 4     ['Prepared Remarks:', 'Operator', 'Greetings, ...      5  2019   msft
# ...                                                 ...    ...   ...    ...
# 2987  ["OperatorGood morning, ladies and gentlemen. ...   3490  2019   coty
# 2988  ["OperatorGood morning, ladies and gentlemen. ...   3491  2019   coty
# 2989  ['Contents:', '', 'Prepared Remarks', 'Questio...   3493  2019   coty
# 2990  ['Prepared Remarks:', 'Operator', "Good mornin...   3494  2018   coty
# 2991  ['Prepared Remarks:', 'Operator', "Good mornin...   3495  2018   coty
#
#                                        clean_transcript  \
# 0      operatorgreetings and welcome to the microsof...
# 1      operatorwelcome to the microsoft fiscal year ...
# 2      operatorwelcome to the microsoft fiscal year ...
# 3      operatorwelcome to the microsoft fiscal year ...
# 4      prepared remarks operator greetings welcome t...
# ...                                                 ...
# 2987   operatorgood morning ladies and gentlemen my ...
# 2988   operatorgood morning ladies and gentlemen my ...
# 2989   contents prepared remarks questions and answe...
# 2990   prepared remarks operator good morning ladies...
# 2991   prepared remarks operator good morning ladies...
#
#                                       clean_transcript2 Next_Available_Day  \
# 0     operatorgreetings welcome microsoft fiscal yea...         2020-05-01
# 1     operatorwelcome microsoft fiscal year 2020 sec...         2020-01-31
# 2     operatorwelcome microsoft fiscal year 2020 fir...         2019-10-24
# 3     operatorwelcome microsoft fiscal year 2019 fou...         2019-07-19
# 4     prepared remarks operator greetings welcome mi...         2019-04-26
# ...                                                 ...                ...
# 2987  operatorgood morning ladies gentlemen name mar...         2019-11-07
# 2988  operatorgood morning ladies gentlemen name mar...         2019-08-29
# 2989  contents prepared remarks questions answers ca...         2019-02-11
# 2990  prepared remarks operator good morning ladies ...         2018-11-08
# 2991  prepared remarks operator good morning ladies ...         2018-08-22
#
#       Date_Adj_Close  Next_Available_Day_Adj_Close  Percent Change  Label
# 0         178.712280                    174.085175       -2.589137      0
# 1         171.830795                    169.294800       -1.475868      0
# 2         136.023209                    138.699264        1.967352      1
# 3         134.761719                    134.959274        0.146596      1
# 4         127.109573                    127.837875        0.572972      1
# ...              ...                           ...             ...    ...
# 2987       12.747121                     12.727539       -0.153617      0
# 2988        9.019238                      9.038573        0.214373      1
# 2989        8.832841                      9.145256        3.536972      1
# 2990        8.078259                      7.742442       -4.157039      0
# 2991       10.642809                     10.827580        1.736107      1
#
# [2992 rows x 15 columns]

# %%
# Write to csv
final.to_csv(r"C:\Users\Ryan\Documents\GitHub\NLP_Final_Project\clean_data_v2.csv")
